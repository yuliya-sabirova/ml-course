# %% [markdown]
# # 5-семинар: Matplotlib және Seaborn көмегімен деректерді визуализациялаудың алғашқы қадамдары
#
# **Семинардың мақсаты:** Matplotlib және Seaborn кітапханаларының негізгі синтаксисімен танысу, негізгі график түрлерін құруды үйрену және олар бойынша алғашқы қорытындылар жасау.
#
# **Баға:** 6 балл (+0.5 бонус).

# %% [markdown]
# ## Кіріспе
#
# Бүгінгі семинарда біз теориядан практикаға көшеміз. Біздің мақсатымыз — тек график құру функцияларын шақырып үйрену ғана емес, сонымен қатар деректерді "көре" бастау, олардың құрылымын түсіну және алғашқы инсайттарды табу. Біз процестің "ішкі жұмысын" түсіну үшін Matplotlib негіздерінен бастаймыз, содан кейін деректерді жылдам және тиімді талдаудың негізгі құралы ретінде Seaborn-ға көшеміз.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Ноутбукта графиктерді көрсетуге арналған команда
# %matplotlib inline

# %% [markdown]
# ## 1-тапсырма. Matplotlib-пен жаттығу (1 балл)
#
# Дәрісте көргеніміздей, Matplotlib — бұл іргетас. Негізгі командаларды бекіту үшін қарапайым графикті "нөлден" бастап құрайық.
#
# 1.  Екі NumPy массивін жасаңыз:
#     *   `x` — 0-ден 45-ке дейінгі 10 нүкте.
#     *   `y` — `x`-тің мәндері.
# 2.  `(x, y)` сызықтық графигін құрыңыз.
# 3.  Графикке қосыңыз:
#     *   Атауы: "Қарапайым сызықтық график"
#     *   X осіне жазу: "X осі"
#     *   Y осіне жазу: "Y осі"
#     *   Сызықты қызыл түсті (`color='red'`) етіп, оның қалыңдығын 3-ке дейін арттырыңыз (`linewidth=3`).

# %%
# Кодыңызды осы жерге жазыңыз

# %% [markdown]
# **Өзін-өзі тексеру сұрағы:** Кодыңыздың әрбір жолы не үшін жауап береді?

# %% [markdown]
# ## 2-тапсырма. Seaborn көмегімен сатылым деректерін талдау (2.5 балл)
#
# Енді `dm_office_sales.csv` файлын талдау үшін Seaborn-ның мүмкіндіктерін пайдаланайық.

# %% [markdown]
# ### 2.1. Деректерді жүктеу және алғашқы шашырау диаграммасы

# %%
df_sales = pd.read_csv('dm_office_sales.csv')

# %% [markdown]
# Жылдық жалақы (`salary`) мен сатылым көлемі (`sales`) арасындағы өзара байланысты зерттеу үшін шашырау диаграммасын (`scatterplot`) құрыңыз.

# %%
# Кодыңызды осы жерге жазыңыз

# %% [markdown]
# **Қорытынды (1-2 сөйлем):** Жалақы мен сатылым арасында көрінетін байланыс бар ма? Жалақы өскен сайын сатылым көлемі арта ма?
#
# *Жауабыңызды осы жерге жазыңыз...*

# %% [markdown]
# ### 2.2. Үшінші өлшемді қосу (`hue`)
#
# Алдыңғы пункттегі кодты көшіріп, нүктелерді бөлімге (`division`) байланысты бояу үшін `hue='division'` параметрін қосыңыз.

# %%
# Кодыңызды осы жерге жазыңыз

# %% [markdown]
# **Қорытынды (1-2 сөйлем):** Белгілі бір бөлімде қызметкерлер салыстырмалы жалақы деңгейінде көбірек сатылым жасайды деп айтуға бола ма?
#
# *Жауабыңызды осы жерге жазыңыз...*

# %% [markdown]
# ## 3-тапсырма. Студенттердің үлгерімін зерттеу (2.5 балл)
#
# `StudentsPerformance.csv` деректер жиынтығына көшіп, оны зерттейік.

# %%
df_perf = pd.read_csv('StudentsPerformance.csv')

# %% [markdown]
# ### 3.1. Таралу гистограммасы (`histplot`)
#
# Математика пәнінен алынған бағалардың (`math score`) таралуына арналған гистограмма құрыңыз. Көрнекілік үшін графикке тығыздық қисығын (`kde=True`) қосыңыз.

# %%
# Кодыңызды осы жерге жазыңыз

# %% [markdown]
# **Қорытынды:** Таралудың пішіні қандай? Ол симметриялы ма ("қоңырау" тәрізді)? Әлде бір жаққа қарай ығысқан ба?
#
# *Жауабыңызды осы жерге жазыңыз...*

# %% [markdown]
# ### 3.2. Қорапты диаграмма (`boxplot`)
#
# `boxplot` көмегімен `parental level of education` бағанының әрбір категориясы үшін жазу пәнінен алынған бағалардың (`writing score`) таралуын салыстырыңыз.

# %%
# Жазулардың оқылуын жақсарту үшін графиктің өлшемін үлкейтіп, жазуларды бұрамыз
plt.figure(figsize=(10,6))
# boxplot-қа арналған кодыңызды осы жерге жазыңыз
plt.xticks(rotation=30);

# %% [markdown]
# **Кеңейтілген қорытынды жазыңыз:**
# *   Ата-аналардың қай тобында балалардың медиандық бағасы ең жоғары?
# *   Қай топта бағалардың шашырауы ең үлкен (ең биік "қорап")?
# *   Графикте шығарындылар ("мұртшалардан" тыс нүктелер) байқала ма? Егер иә болса, қай топтарда?
#
# *Жауабыңызды осы жерге жазыңыз...*

# %% [markdown]
# ## 4-тапсырма (Бонус). Орташа мәндерді `barplot` көмегімен салыстыру (0.5 балл)
#
# Біз бағалардың *таралуын* салыстыру үшін `boxplot` қолдандық. Ал *орташа* бағаларды қалай салыстыруға болады? Бұл үшін `barplot` өте қолайлы.
#
# 1.  `StudentsPerformance.csv` деректерін пайдаланып, студенттің тестке дайындық курсынан (`test preparation course`) өтуіне байланысты математика пәнінен орташа бағасын (`math score`) салыстыру үшін `barplot` құрыңыз.
# 2.  **Қорытынды (1 сөйлем):** Орташа бағаларға сүйенсек, дайындық курсы көмектесе ме?

# %%
# Кодыңызды осы жерге жазыңыз

# %% [markdown]
# **Қорытынды:**
#
# *Жауабыңызды осы жерге жазыңыз...*
