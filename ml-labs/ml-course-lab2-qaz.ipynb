# %% [markdown]
# # №2 Зертханалық жұмыс: NumPy-ға кіріспе
#
# **Курс:** Машиналық оқыту

# %% [markdown]
# ### Студент туралы ақпарат
#
# **Аты-жөні:** *<студент бұл жерге өз деректерін жазуы керек>*
#
# **Тобы:** *<студент бұл жерге өз деректерін жазуы керек>*
#
# Орындау нәтижесін **АТЫЖӨНІ_тобы_Lab2.ipynb** атауымен бір Jupyter-блокнот (.ipynb) түрінде тапсыру қажет. Мысалы: PopkovDamir_MCM-16-4_Lab2.ipynb
#
# Файлды [GoogleDisk](https://drive.google.com/drive/u/0/folders/1Y_56cvEbeTgyk9PkI7u0zq1UBDcuWNqE) жүктейміз

# %% [markdown]
# ### Нұсқа нөмірін анықтау
#
# Сіздің нұсқаңыз келесі формула бойынша есептеледі: **ID картаның соңғы нөмірі % 4**. Егер сізде 0 шықса, онда сіздің нұсқаңыз 4.
#
# Мысалы, менің ID-ім 156789. Демек, 9 % 4 = 1. Менде 1-нұсқа.
#
# **Дедлайн - келесі аптаның зертханалық сабағына дейін**. Егер келесі сабақ, мысалы, 23.09 болса, демек, дедлайн 22.09 23:59.
#
# Тапсырмалар дедлайннан кейін **қабылданбайды**. Тіпті жартылай. Тіпті ширек балл үшін де.

# %% [markdown]
# ### Бағалау саясаты және академиялық адалдық
#
# **Жұмыс үшін максималды баға: 10 балл.**
#
# Баллдар келесідей бөлінеді:
#
# | Тапсырма | Максималды балл | Сипаттамасы |
# |:---|:---|:---|
# | 1-тапсырма | **1.5 балл** | NumPy массивтерін әртүрлі тәсілдермен құру (барлық ішкі тапсырмалар). |
# | 2-тапсырма | **1.5 балл** | Индекстеу және кесінділерді алу (slicing) (барлық ішкі тапсырмалар). |
# | 3-тапсырма | **1.5 балл** | Арифметикалық операциялар және хабар тарату (broadcasting). |
# | 4-тапсырма | **1.5 балл** | Шартты таңдау арқылы деректерді сүзу. |
# | 5-тапсырма | **1.5 балл** | Осьтер бойынша агрегаттаушы функцияларды қолдану. |
# | 6-тапсырма | **2.5 балл** | Machine Learning стиліндегі кешенді есепті шешу. |
#
# **Академиялық адалдық саясаты:**
#
# Идеяларды бірлесіп талқылауға болады, бірақ **кодты өзіңіз жазуыңыз керек**. Бірдей деп танылған (плагиат) жұмыстар барлық қатысқан студенттер үшін қайта тапсыру мүмкіндігінсіз **0 баллмен** бағаланады.
#
# **Жұмысыңызды қорғауға дайын болыңыз**. Мен кез-келген студентті зертханалық жұмысты ауызша қорғауға шақыру құқығын өзіме қалдырамын, онда оның кодының кез-келген бөлігінің логикасын түсіндіруді сұраймын.

# %% [markdown]
# ---

# %% [markdown]
# ### 1-тапсырма: Массивтерді құру (Максимум: 1.5 балл)
#
# **Сіздің міндетіңіз:** Массивтерді құрудың әртүрлі тәсілдерін жаттықтыру үшін **барлық төрт** ішкі тапсырманы орындаңыз.
#
# *   **1.1-ішкі тапсырма:** 10-нан 40-қа дейінгі (қоса алғанда) бүтін сандардан 3 қадаммен тұратын 1D-массив құрыңыз. Содан кейін оны 3x4 өлшемді матрицаға айналдырыңыз.
#
# *   **1.2-ішкі тапсырма:** 0-ден 5-ке дейінгі (қоса алғанда) аралықта бір-бірінен бірдей қашықтықта орналасқан 15 саннан тұратын 1D-массив құрыңыз. Содан кейін оны 3x5 өлшемді матрицаға айналдырыңыз.
#
# *   **1.3-ішкі тапсырма:** Нөлдермен толтырылған 4x4 өлшемді матрица құрыңыз. Содан кейін осы матрицаның бас диагоналін 1, 2, 3, 4 сандары болатындай етіп өзгертіңіз.
#
# *   **1.4-ішкі тапсырма:** 5x5 өлшемді бірлік матрицасын құрыңыз. Содан кейін бүкіл матрицаны 7 санына көбейтіңіз.
#
# > **Кеңестер:**
# > * `np.arange()`, `np.linspace()`, `np.zeros()`, `np.eye()` функцияларын қолданыңыз.
# > * Пішінді өзгерту үшін `.reshape()` әдісін қолданыңыз.
# > * Диагональға қол жеткізу үшін `np.fill_diagonal()` немесе `np.diag()` қолдануға болады.

# %%
import numpy as np

# СІЗДІҢ КОДЫҢЫЗ ОСЫ ЖЕРДЕ
# Барлық 4 ішкі тапсырманы осы ұяшықта немесе өзіңізге ыңғайлы бірнеше ұяшықта орындаңыз.

# %% [markdown]
# ### 2-тапсырма: Индекстеу және кесінділер (Максимум: 1.5 балл)
#
# **Сіздің міндетіңіз:** Берілген `data` матрицасы үшін элементтерді шығарып алу бойынша **барлық төрт** ішкі тапсырманы орындаңыз.
#
# ```python
# data = np.arange(1, 26).reshape(5, 5)
# ```
#
# *   **2.1-ішкі тапсырма:** 3-ші жол мен 4-ші бағанда орналасқан элементті (`19` мәні) шығарыңыз.
#
# *   **2.2-ішкі тапсырма:** Массивтің екінші жолын толығымен шығарыңыз (элементтер `[6, 7, 8, 9, 10]`).
#
# *   **2.3-ішкі тапсырма:** Массивтің үшінші бағанын толығымен шығарыңыз (элементтер `[3, 8, 13, 18, 23]`).
#
# *   **2.4-ішкі тапсырма:** Жоғарғы оң жақ бұрыштан 2x2 ішкі матрицасын шығарыңыз (элементтер `[[4, 5], [9, 10]]`).
#
# > **Кеңестер:**
# > * NumPy-да индекстеу 0-ден басталатынын ұмытпаңыз.
# > * Кесінділер үшін `array[row, col]` немесе `array[start:stop]` синтаксисін қолданыңыз.

# %%
# Тапсырмаға арналған деректер
data = np.arange(1, 26).reshape(5, 5)

# СІЗДІҢ КОДЫҢЫЗ ОСЫ ЖЕРДЕ
# Барлық 4 ішкі тапсырманы орындаңыз.

# %% [markdown]
# ### 3-тапсырма: Массивтермен операциялар (Максимум: 1.5 балл)
#
# **Сіздің міндетіңіз:** Нұсқаңызға сәйкес массивтермен операцияларды орындаңыз.
#
# *   **1-нұсқа:** `arr = np.arange(1, 10).reshape(3, 3)` массиві берілген. Массивтің әрбір элементіне 5 санын қосып, содан кейін алынған массивтің әрбір элементінен квадрат түбір табыңыз.
#
# *   **2-нұсқа:** `a = np.array([[1, 2], [3, 4]])` және `b = np.array([[5, 6], [7, 8]])` екі массиві берілген. Олардың элемент бойынша көбейтіндісін орындаңыз. Содан кейін нәтиженің әрбір элементін 2-дәрежеге шығарыңыз.
#
# *   **3-нұсқа:** `matrix = np.arange(1, 7).reshape(2, 3)` массиві және `vector = np.array([10, 20, 30])` векторы берілген. Хабар тарату (broadcasting) механизмін қолданып, `vector`-ды `matrix`-тің әрбір жолына қосыңыз.
#
# *   **4-нұсқа:** `matrix = np.arange(1, 10).reshape(3, 3)` массиві және `vector = np.array([1, 2, 3])` векторы берілген. `matrix`-тің әрбір бағанын `vector`-дың сәйкес элементіне көбейтіңіз. (Вектордың пішінін өзгерту қажет болуы мүмкін).
#
# > **Кеңестер:**
# > * Стандартты арифметикалық операторларды `+`, `*`, `**` қолданыңыз.
# > * Квадрат түбір үшін `np.sqrt()` функциясын қолданыңыз.
# > * 4-нұсқа үшін дұрыс хабар тарату үшін вектордың пішінін `(3, 1)`-ге өзгертіңіз.

# %%
# СІЗДІҢ КОДЫҢЫЗ ОСЫ ЖЕРДЕ
# Түсініктемеде өз нұсқаңыздың нөмірін көрсетуді ұмытпаңыз!

# %% [markdown]
# ### 4-тапсырма: Шартты таңдау (Boolean Indexing) (Максимум: 1.5 балл)
#
# **Сіздің міндетіңіз:** Берілген `data` матрицасы үшін нұсқаңыздың шарты бойынша элементтерді сүзіңіз.
#
# ```python
# np.random.seed(42) # нәтижелердің қайталануы үшін
# data = np.random.randint(1, 101, size=(5, 5))
# ```
#
# *   **1-нұсқа:** `data`-дан 80-нен үлкен барлық элементтерді таңдаңыз.
#
# *   **2-нұсқа:** `data`-дан барлық жұп элементтерді таңдаңыз. (Кеңес: `x % 2 == 0`).
#
# *   **3-нұсқа:** `data`-дан 20-дан 50-ге дейінгі (қоса алғанда) аралықтағы барлық элементтерді таңдаңыз.
#
# *   **4-нұсқа:** `data`-дағы 30-дан кіші барлық элементтерді 0 мәнімен алмастырыңыз.
#
# > **Кеңестер:**
# > * Буль маскасын жасаңыз: `mask = data > 80`.
# > * Масканы массивке қолданыңыз: `data[mask]`.
# > * Құрама шарттар үшін `&` (ЖӘНЕ) және `|` (НЕМЕСЕ) операторларын қолданыңыз, әр шартты жақшаға алыңыз.

# %%
# Барлық нұсқаларға арналған деректер
np.random.seed(42)
data = np.random.randint(1, 101, size=(5, 5))

# СІЗДІҢ КОДЫҢЫЗ ОСЫ ЖЕРДЕ
# Түсініктемеде өз нұсқаңыздың нөмірін көрсетуді ұмытпаңыз!

# %% [markdown]
# ### 5-тапсырма: Осьтер бойынша агрегаттау (Максимум: 1.5 балл)
#
# **Сіздің міндетіңіз:** Берілген `data` матрицасы үшін нұсқаңызға сәйкес көрсетілген ось бойынша агрегаттық статистиканы есептеңіз. `data` — бұл 4 студенттің 3 емтихан бойынша бағалары деп есептейік.
#
# *   **1-нұсқа:** Әр емтихан бойынша орташа баллды табыңыз (әр бағанның орташа мәні).
#
# *   **2-нұсқа:** Әр студенттің баллдарының қосындысын табыңыз (әр жолдың қосындысы).
#
# *   **3-нұсқа:** Әр емтихан бойынша максималды баллды табыңыз (әр бағандағы максимум).
#
# *   **4-нұсқа:** Әр студенттің минималды баллын табыңыз (әр жолдағы минимум).
#
# > **Кеңестер:**
# > * `data.mean()`, `data.sum()`, `data.max()`, `data.min()` қолданыңыз.
# > * Бағандар бойынша операциялар үшін `axis=0` және жолдар бойынша операциялар үшін `axis=1` көрсетіңіз.

# %%
# Барлық нұсқаларға арналған деректер
data = np.array([[85, 92, 78], [95, 88, 91], [76, 85, 89], [98, 91, 93]])

# СІЗДІҢ КОДЫҢЫЗ ОСЫ ЖЕРДЕ
# Түсініктемеде өз нұсқаңыздың нөмірін көрсетуді ұмытпаңыз!

# %% [markdown]
# ### 6-тапсырма: Кешенді есеп (Максимум: 2.5 балл)
#
# **Сіздің міндетіңіз:** Нұсқаңыздағы есепті NumPy-мен жұмыс істеудің бірнеше дағдысын біріктіріп шешіңіз.
#
# *   **1-нұсқа: Модельдің болжамы.** Белгілер матрицасы `features` (3 нысан, 2 белгі) және салмақтар векторы `weights` берілген. `prediction = features @ weights + bias` формуласы бойынша модельдің болжамын есептеңіз. Нәтижені шығарыңыз.
#     ```python
#     features = np.array([,,])
#     weights = np.array([0.5, -0.3])
#     bias = 0.1
#     ```
#
# *   **2-нұсқа: Деректерді нормалау (Min-Max Scaling).** `data` деректер матрицасы берілген. Әр бағандағы мәндер 0-ден 1-ге дейінгі аралықта болатындай етіп нормалаңыз. Формула: `(X - min) / (max - min)`. Осы формуланы әр бағанға қолданыңыз.
#     ```python
#     data = np.array([,,], dtype=float)
#     ```
#
# *   **3-нұсқа: Орташа квадраттық қатені (MSE) есептеу.** `y_True` (шынайы мәндер) және `y_pred` (болжанған мәндер) екі векторы берілген. `mean((y_True - y_pred)^2)` формуласы бойынша MSE есептеңіз.
#     ```python
#     y_True = np.array([2.5, 5.0, 3.5, 6.2])
#     y_pred = np.array([2.8, 4.5, 4.0, 5.9])
#     ```
#
# *   **4-нұсқа: Жаңа белгі қосу.** "Бой (см)" және "салмақ (кг)" белгілері бар `data` деректер матрицасы берілген. `салмақ / (метрмен_бой)^2` формуласы бойынша есептелетін Дене Салмағының Индексі (ДСИ) атты жаңа белгі жасаңыз. Бұл белгіні бастапқы матрицаға жаңа баған ретінде қосыңыз.
#     ```python
#     data = np.array([,,], dtype=float)
#     ```
#
# > **Кеңестер:**
# > * **1-нұсқа:** Матрицалық көбейту үшін `@` операторын қолданыңыз.
# > * **2-нұсқа:** Бағандар бойынша `min` және `max` табыңыз (`axis=0`), содан кейін хабар тарату (broadcasting) механизмін қолданыңыз.
# > * **3-нұсқа:** Барлық операцияларды (азайту, квадраттау, орташа мән табу) тікелей массивтермен орындауға болады.
# > * **4-нұсқа:** Алдымен бағандарды шығарып алыңыз, есептеулерді орындаңыз (бойды метрге айналдыруды ұмытпаңыз), жаңа бағанның пішінін `(n, 1)`-ге өзгертіп, біріктіру үшін `np.hstack()` функциясын қолданыңыз.

# %%
# СІЗДІҢ КОДЫҢЫЗ ОСЫ ЖЕРДЕ
# Түсініктемеде өз нұсқаңыздың нөмірін көрсетуді ұмытпаңыз!
