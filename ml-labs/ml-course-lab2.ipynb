# %% [markdown]
# # Лабораторная работа №2: Введение в NumPy
#
# **Курс:** Машинное обучение

# %% [markdown]
# ### Информация о студенте
#
# **ФИО:** *<здесь студент должен вписать свои данные>*
#
# **Группа:** *<здесь студент должен вписать свои данные>*
#
# Результат выполнения необходимо сдать в виде одного Jupyter-блокнота (.ipynb) с названием **ФИО_группа_Lab2.ipynb**. Пример: PopkovDamir_MCM-16-4_Lab2.ipynb
#
# Файл загружаем на [GoogleDisk](https://drive.google.com/drive/u/0/folders/1Y_56cvEbeTgyk9PkI7u0zq1UBDcuWNqE)

# %% [markdown]
# ### Определение номера варианта
#
# Ваш вариант вычисляется по формуле: **последний номер ID карты % 4**. Если у Вас 0, значит, Ваш вариант 4.
#
# Например, мой ID 156789. Значит, 9 % 4 = 1. У меня 1 вариант
#
# **Дедлайн - до лабораторного занятия следующей недели**. Если следующее занятие, например, 23.09, значит, дедлайн 22.09 23:59.
#
# Задания после дедлайна **не принимаются**. Даже частично. Даже за четверть баллов.

# %% [markdown]
# ### Политика выставления оценок и академическая честность
#
# **Максимальная оценка за работу: 10 баллов.**
#
# Баллы распределяются следующим образом:
#
# | Задание | Максимальный балл | Описание |
# |:---|:---|:---|
# | Задание 1 | **1.5 балла** | Создание массивов NumPy различными способами (все подзадания). |
# | Задание 2 | **1.5 балла** | Индексация и извлечение срезов (slicing) (все подзадания). |
# | Задание 3 | **1.5 балла** | Арифметические операции и вещание (broadcasting). |
# | Задание 4 | **1.5 балла** | Фильтрация данных с помощью условного выбора. |
# | Задание 5 | **1.5 балла** | Применение агрегирующих функций по осям. |
# | Задание 6 | **2.5 балла** | Решение комплексной задачи в стиле Machine Learning. |
#
# **Политика академической честности:**
#
# Совместное обсуждение идей, но **код вы должны писать самостоятельно**. Работы, которые будут признаны идентичными (плагиатом), будут оценены в **0 баллов** для всех вовлеченных студентов без возможности пересдачи.
#
# **Будьте готовы защитить свою работу**. Я оставляю за собой право вызвать любого студента для устной защиты лабораторной работы, где попрошу объяснить логику любой части его кода.

# %% [markdown]
# ---

# %% [markdown]
# ### Задание 1: Создание массивов (Максимум: 1.5 балла)
#
# **Ваша задача:** Выполните **все четыре** подзадания, чтобы попрактиковаться в различных способах создания массивов.
#
# *   **Подзадание 1.1:** Создайте 1D-массив, содержащий целые числа от 10 до 40 (включительно) с шагом 3. Затем преобразуйте его в матрицу размером 3x4.
#
# *   **Подзадание 1.2:** Создайте 1D-массив из 15 равноудаленных чисел в диапазоне от 0 до 5 (включительно). Затем преобразуйте его в матрицу размером 3x5.
#
# *   **Подзадание 1.3:** Создайте матрицу размером 4x4, заполненную нулями. Затем измените главную диагональ этой матрицы так, чтобы она содержала числа 1, 2, 3, 4.
#
# *   **Подзадание 1.4:** Создайте единичную матрицу размером 5x5. Затем умножьте всю матрицу на число 7.
#
# > **Подсказки:**
# > * Используйте функции `np.arange()`, `np.linspace()`, `np.zeros()`, `np.eye()`.
# > * Для изменения формы используйте метод `.reshape()`.
# > * Для доступа к диагонали можно использовать `np.fill_diagonal()` или `np.diag()`.

# %%
import numpy as np

# ВАШ КОД ЗДЕСЬ
# Выполните все 4 подзадания в этой ячейке или в нескольких, как вам удобнее.

# %% [markdown]
# ### Задание 2: Индексация и срезы (Максимум: 1.5 балла)
#
# **Ваша задача:** Для заданной матрицы `data` выполните **все четыре** подзадания по извлечению элементов.
#
# ```python
# data = np.arange(1, 26).reshape(5, 5)
# ```
#
# *   **Подзадание 2.1:** Извлеките элемент, который находится в 3-й строке и 4-м столбце (значение `19`).
#
# *   **Подзадание 2.2:** Извлеките всю вторую строку массива (элементы `[6, 7, 8, 9, 10]`).
#
# *   **Подзадание 2.3:** Извлеките весь третий столбец массива (элементы `[3, 8, 13, 18, 23]`).
#
# *   **Подзадание 2.4:** Извлеките подматрицу 2x2 из правого верхнего угла (элементы `[[4, 5], [9, 10]]`).
#
# > **Подсказки:**
# > * Помните, что индексация в NumPy начинается с 0.
# > * Используйте синтаксис `array[row, col]` или `array[start:stop]` для срезов.

# %%
# Данные для задания
data = np.arange(1, 26).reshape(5, 5)

# ВАШ КОД ЗДЕСЬ
# Выполните все 4 подзадания.

# %% [markdown]
# ### Задание 3: Операции над массивами (Максимум: 1.5 балла)
#
# **Ваша задача:** Выполните операции над массивами согласно вашему варианту.
#
# *   **Вариант 1:** Дан массив `arr = np.arange(1, 10).reshape(3, 3)`. Прибавьте к каждому элементу массива число 5, а затем найдите квадратный корень каждого элемента полученного массива.
#
# *   **Вариант 2:** Даны два массива `a = np.array([[1, 2], [3, 4]])` и `b = np.array([[5, 6], [7, 8]])`. Выполните их поэлементное умножение. Затем возведите каждый элемент результата в степень 2.
#
# *   **Вариант 3:** Дан массив `matrix = np.arange(1, 7).reshape(2, 3)` и вектор `vector = np.array([10, 20, 30])`. Прибавьте `vector` к каждой строке `matrix`, используя механизм вещания (broadcasting).
#
# *   **Вариант 4:** Дан массив `matrix = np.arange(1, 10).reshape(3, 3)` и вектор `vector = np.array([1, 2, 3])`. Умножьте каждый столбец `matrix` на соответствующий элемент `vector`. (Вам может понадобиться изменить форму вектора).
#
# > **Подсказки:**
# > * Используйте стандартные арифметические операторы `+`, `*`, `**`.
# > * Для квадратного корня используйте `np.sqrt()`.
# > * Для варианта 4 измените форму вектора на `(3, 1)` для корректного вещания.

# %%
# ВАШ КОД ЗДЕСЬ
# Не забудьте указать номер вашего варианта в комментарии!

# %% [markdown]
# ### Задание 4: Условный выбор (Boolean Indexing) (Максимум: 1.5 балла)
#
# **Ваша задача:** Для заданной матрицы `data` отфильтруйте элементы по условию вашего варианта.
#
# ```python
# np.random.seed(42) # для воспроизводимости результатов
# data = np.random.randint(1, 101, size=(5, 5))
# ```
#
# *   **Вариант 1:** Выберите все элементы из `data`, которые больше 80.
#
# *   **Вариант 2:** Выберите все элементы из `data`, которые являются четными. (Подсказка: `x % 2 == 0`).
#
# *   **Вариант 3:** Выберите все элементы из `data`, которые находятся в диапазоне от 20 до 50 (включительно).
#
# *   **Вариант 4:** Замените все элементы в `data`, которые меньше 30, на значение 0.
#
# > **Подсказки:**
# > * Создайте булеву маску: `mask = data > 80`.
# > * Примените маску к массиву: `data[mask]`.
# > * Для составных условий используйте `&` (И) и `|` (ИЛИ), оборачивая каждое условие в скобки.

# %%
# Данные для всех вариантов
np.random.seed(42)
data = np.random.randint(1, 101, size=(5, 5))

# ВАШ КОД ЗДЕСЬ
# Не забудьте указать номер вашего варианта в комментарии!

# %% [markdown]
# ### Задание 5: Агрегирование по осям (Максимум: 1.5 балла)
#
# **Ваша задача:** Для заданной матрицы `data` вычислите агрегирующую статистику по указанной оси согласно вашему варианту. Представим, что `data` — это оценки 4 студентов по 3 экзаменам.
#
# ```python
# data = np.array([,,,])
# ```
#
# *   **Вариант 1:** Найдите средний балл по каждому экзамену (среднее по каждому столбцу).
#
# *   **Вариант 2:** Найдите сумму баллов для каждого студента (сумма по каждой строке).
#
# *   **Вариант 3:** Найдите максимальный балл по каждому экзамену (максимум в каждом столбце).
#
# *   **Вариант 4:** Найдите минимальный балл для каждого студента (минимум в каждой строке).
#
# > **Подсказки:**
# > * Используйте `data.mean()`, `data.sum()`, `data.max()`, `data.min()`.
# > * Укажите `axis=0` для операций по столбцам и `axis=1` для операций по строкам.

# %%
# Данные для всех вариантов
data = np.array([[85, 92, 78], [95, 88, 91], [76, 85, 89], [98, 91, 93]])

# ВАШ КОД ЗДЕСЬ
# Не забудьте указать номер вашего варианта в комментарии!

# %% [markdown]
# ### Задание 6: Комплексная задача (Максимум: 2.5 балла)
#
# **Ваша задача:** Решите задачу из вашего варианта, комбинируя несколько навыков работы с NumPy.
#
# *   **Вариант 1: Предсказание модели.** Дана матрица признаков `features` (3 объекта, 2 признака) и вектор весов `weights`. Вычислите предсказание модели по формуле `prediction = features @ weights + bias`. Выведите результат.
#     ```python
#     features = np.array([,,])
#     weights = np.array([0.5, -0.3])
#     bias = 0.1
#     ```
#
# *   **Вариант 2: Нормализация данных (Min-Max Scaling).** Дана матрица данных `data`. Нормализуйте её так, чтобы значения в каждом столбце находились в диапазоне от 0 до 1. Формула: `(X - min) / (max - min)`. Примените эту формулу к каждому столбцу.
#     ```python
#     data = np.array([,,], dtype=float)
#     ```
#
# *   **Вариант 3: Расчет среднеквадратичной ошибки (MSE).** Даны два вектора: `y_true` (истинные значения) и `y_pred` (предсказанные значения). Вычислите MSE по формуле `mean((y_true - y_pred)^2)`.
#     ```python
#     y_true = np.array([2.5, 5.0, 3.5, 6.2])
#     y_pred = np.array([2.8, 4.5, 4.0, 5.9])
#     ```
#
# *   **Вариант 4: Добавление нового признака.** Дана матрица данных `data` с признаками "рост (см)" и "вес (кг)". Создайте новый признак — Индекс Массы Тела (ИМТ), рассчитанный по формуле `вес / (рост_в_метрах)^2`. Добавьте этот признак в виде нового столбца к исходной матрице.
#     ```python
#     data = np.array([,,], dtype=float)
#     ```
#
# > **Подсказки:**
# > * **Вариант 1:** Используйте оператор `@` для матричного умножения.
# > * **Вариант 2:** Найдите `min` и `max` по столбцам (`axis=0`), затем используйте вещание (broadcasting).
# > * **Вариант 3:** Все операции (вычитание, возведение в квадрат, нахождение среднего) можно выполнить напрямую с массивами.
# > * **Вариант 4:** Сначала извлеките столбцы, выполните вычисления (не забудьте перевести рост в метры), измените форму нового столбца на `(n, 1)` и используйте `np.hstack()` для объединения.

# %%
# ВАШ КОД ЗДЕСЬ
# Не забудьте указать номер вашего варианта в комментарии!
